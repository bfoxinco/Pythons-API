# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime
import random
from pprint import pprint
import os
import csv

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# url + api key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create empty lists to store the data
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

record_counter = 0
set_counter = 0

print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

# use for loop to add city to base url
for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(query_url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=rikitea
# Processing record 2 of set 0 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hithadhoo
# Processing record 3 of set 0 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=saleaula
# City not found!
# Processing record 4 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hobart
# Processing record 5 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=albany
# Processing record 6 of set 0 | mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mujiayingzi
# Processing record 7 of set 0 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tiznit
# Processing record 8 of set 0 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=klaksvik
# Processing record 9 of set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=puerto ayora
# Processing record 10 of set 0 | catamarca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=catamarca
# Processing record 11 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ushuaia
# Processing record 12 of set 0 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bonavista
# Processing record 13 of set 0 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bargal
# City not found!
# Processing record 14 of set 0 | kamloops
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kamloops
# Processing record 15 of set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hermanus
# Processing record 16 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mataura
# Processing record 17 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=busselton
# Processing record 18 of set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cape town
# Processing record 19 of set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=jamestown
# Processing record 20 of set 0 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=thompson
# Processing record 21 of set 0 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tommot
# Processing record 22 of set 0 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kruisfontein
# Processing record 23 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=punta arenas
# Processing record 24 of set 0 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=buala
# Processing record 25 of set 0 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kodiak
# Processing record 26 of set 0 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lebu
# Processing record 27 of set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kapaa
# Processing record 28 of set 0 | catuday
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=catuday
# Processing record 29 of set 0 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ponta do sol
# Processing record 30 of set 0 | tarakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tarakan
# Processing record 31 of set 0 | hunza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hunza
# City not found!
# Processing record 32 of set 0 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=marzuq
# Processing record 33 of set 0 | vagur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=vagur
# Processing record 34 of set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=vaini
# Processing record 35 of set 0 | alberton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=alberton
# Processing record 36 of set 0 | crab hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=crab hill
# City not found!
# Processing record 37 of set 0 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=barrow
# Processing record 38 of set 0 | jacobabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=jacobabad
# Processing record 39 of set 0 | tynda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tynda
# Processing record 40 of set 0 | laurel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=laurel
# Processing record 41 of set 0 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=belushya guba
# City not found!
# Processing record 42 of set 0 | nador
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nador
# Processing record 43 of set 0 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nikolskoye
# Processing record 44 of set 0 | urucara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=urucara
# Processing record 45 of set 0 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ugoofaaru
# Processing record 46 of set 0 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=san patricio
# Processing record 47 of set 0 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=fortuna
# Processing record 48 of set 0 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=praia
# Processing record 49 of set 0 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=barentsburg
# City not found!
# Processing record 50 of set 0 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mount gambier
# Processing record 0 of set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cherskiy
# Processing record 1 of set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=castro
# Processing record 2 of set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=saint-philippe
# Processing record 3 of set 1 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=shenjiamen
# Processing record 4 of set 1 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bonthe
# Processing record 5 of set 1 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=borogontsy
# Processing record 6 of set 1 | kochi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kochi
# Processing record 7 of set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hilo
# Processing record 8 of set 1 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=namatanai
# Processing record 9 of set 1 | waitati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=waitati
# Processing record 10 of set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hasaki
# Processing record 11 of set 1 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=honningsvag
# Processing record 12 of set 1 | ji-parana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ji-parana
# City not found!
# Processing record 13 of set 1 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=aklavik
# Processing record 14 of set 1 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cockburn town
# Processing record 15 of set 1 | surt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=surt
# Processing record 16 of set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bethel
# Processing record 17 of set 1 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mogadishu
# Processing record 18 of set 1 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=pitimbu
# Processing record 19 of set 1 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ancud
# Processing record 20 of set 1 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=taoudenni
# Processing record 21 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bluff
# Processing record 22 of set 1 | kuusamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kuusamo
# Processing record 23 of set 1 | semey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=semey
# Processing record 24 of set 1 | bandar-e lengeh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bandar-e lengeh
# Processing record 25 of set 1 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=matara
# Processing record 26 of set 1 | nisia floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nisia floresta
# Processing record 27 of set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=souillac
# Processing record 28 of set 1 | baft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=baft
# Processing record 29 of set 1 | lagos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lagos
# Processing record 30 of set 1 | nanchong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nanchong
# Processing record 31 of set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=amderma
# City not found!
# Processing record 32 of set 1 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=waipawa
# Processing record 33 of set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=butaritari
# Processing record 34 of set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=qaanaaq
# Processing record 35 of set 1 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=porto novo
# Processing record 36 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bredasdorp
# Processing record 37 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tasiilaq
# Processing record 38 of set 1 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mayo
# Processing record 39 of set 1 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=port keats
# Processing record 40 of set 1 | santa rosalia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=santa rosalia
# Processing record 41 of set 1 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ayan
# Processing record 42 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mar del plata
# Processing record 43 of set 1 | zalantun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=zalantun
# Processing record 44 of set 1 | price
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=price
# Processing record 45 of set 1 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lorengau
# Processing record 46 of set 1 | lunenburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lunenburg
# Processing record 47 of set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=port alfred
# Processing record 48 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=atuona
# Processing record 49 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=avarua
# Processing record 50 of set 1 | sulangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sulangan
# Processing record 0 of set 2 | bafoulabe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bafoulabe
# Processing record 1 of set 2 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=honiara
# Processing record 2 of set 2 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=paita
# Processing record 3 of set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mahebourg
# Processing record 4 of set 2 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=grand river south east
# City not found!
# Processing record 5 of set 2 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=coquimbo
# Processing record 6 of set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=new norfolk
# Processing record 7 of set 2 | zimapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=zimapan
# Processing record 8 of set 2 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=yenagoa
# Processing record 9 of set 2 | ruidoso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ruidoso
# Processing record 10 of set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bambous virieux
# Processing record 11 of set 2 | brownsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=brownsville
# Processing record 12 of set 2 | gotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=gotsu
# Processing record 13 of set 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ribeira grande
# Processing record 14 of set 2 | balabac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=balabac
# Processing record 15 of set 2 | petauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=petauke
# Processing record 16 of set 2 | vydrino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=vydrino
# Processing record 17 of set 2 | elizabeth city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=elizabeth city
# Processing record 18 of set 2 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=beringovskiy
# Processing record 19 of set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=east london
# Processing record 20 of set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=carnarvon
# Processing record 21 of set 2 | toftir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=toftir
# City not found!
# Processing record 22 of set 2 | gravelbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=gravelbourg
# Processing record 23 of set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=yellowknife
# Processing record 24 of set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bengkulu
# Processing record 25 of set 2 | genhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=genhe
# Processing record 26 of set 2 | buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=buin
# Processing record 27 of set 2 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bambanglipuro
# Processing record 28 of set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=provideniya
# Processing record 29 of set 2 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=komsomolskiy
# Processing record 30 of set 2 | sedelnikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sedelnikovo
# City not found!
# Processing record 31 of set 2 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=port macquarie
# Processing record 32 of set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=norman wells
# Processing record 33 of set 2 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=turukhansk
# Processing record 34 of set 2 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=saint-francois
# Processing record 35 of set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nizhneyansk
# City not found!
# Processing record 36 of set 2 | matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=matagami
# Processing record 37 of set 2 | gisborne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=gisborne
# Processing record 38 of set 2 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sorland
# Processing record 39 of set 2 | akita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=akita
# Processing record 40 of set 2 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sur
# Processing record 41 of set 2 | iseyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=iseyin
# Processing record 42 of set 2 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=la ronge
# Processing record 43 of set 2 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=gigmoto
# Processing record 44 of set 2 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=camacha
# Processing record 45 of set 2 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=te anau
# Processing record 46 of set 2 | merritt island
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=merritt island
# Processing record 47 of set 2 | tahoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tahoua
# Processing record 48 of set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tuktoyaktuk
# Processing record 49 of set 2 | hun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hun
# Processing record 50 of set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=chuy
# Processing record 0 of set 3 | nyuksenitsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nyuksenitsa
# Processing record 1 of set 3 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=alyangula
# Processing record 2 of set 3 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=college
# Processing record 3 of set 3 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=illoqqortoormiut
# City not found!
# Processing record 4 of set 3 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=taolanaro
# City not found!
# Processing record 5 of set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tiksi
# Processing record 6 of set 3 | hendersonville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hendersonville
# Processing record 7 of set 3 | linhares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=linhares
# Processing record 8 of set 3 | toamasina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=toamasina
# Processing record 9 of set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=victoria
# Processing record 10 of set 3 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=rocha
# Processing record 11 of set 3 | tanhuato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tanhuato
# City not found!
# Processing record 12 of set 3 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=toliary
# City not found!
# Processing record 13 of set 3 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cidreira
# Processing record 14 of set 3 | great yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=great yarmouth
# Processing record 15 of set 3 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=baykit
# Processing record 16 of set 3 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=avera
# Processing record 17 of set 3 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tsihombe
# City not found!
# Processing record 18 of set 3 | tabuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tabuk
# Processing record 19 of set 3 | termiz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=termiz
# Processing record 20 of set 3 | boma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=boma
# Processing record 21 of set 3 | natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=natal
# Processing record 22 of set 3 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hambantota
# Processing record 23 of set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=chokurdakh
# Processing record 24 of set 3 | naumburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=naumburg
# Processing record 25 of set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=upernavik
# Processing record 26 of set 3 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cam ranh
# Processing record 27 of set 3 | santa elena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=santa elena
# Processing record 28 of set 3 | lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lima
# Processing record 29 of set 3 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hofn
# Processing record 30 of set 3 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=deputatskiy
# Processing record 31 of set 3 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=baruun-urt
# Processing record 32 of set 3 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=saint george
# Processing record 33 of set 3 | poiana lacului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=poiana lacului
# Processing record 34 of set 3 | las cruces
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=las cruces
# Processing record 35 of set 3 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=zhigansk
# Processing record 36 of set 3 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=vila franca do campo
# Processing record 37 of set 3 | zhigalovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=zhigalovo
# Processing record 38 of set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kaitangata
# Processing record 39 of set 3 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kavaratti
# Processing record 40 of set 3 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=airai
# Processing record 41 of set 3 | miedzyrzec podlaski
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=miedzyrzec podlaski
# Processing record 42 of set 3 | himora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=himora
# City not found!
# Processing record 43 of set 3 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=peniche
# Processing record 44 of set 3 | kusk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kusk
# City not found!
# Processing record 45 of set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sitka
# Processing record 46 of set 3 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nanortalik
# Processing record 47 of set 3 | manacapuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=manacapuru
# Processing record 48 of set 3 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=praia da vitoria
# Processing record 49 of set 3 | yecla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=yecla
# Processing record 50 of set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=saldanha
# Processing record 0 of set 4 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nuuk
# Processing record 1 of set 4 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bilma
# Processing record 2 of set 4 | porto empedocle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=porto empedocle
# Processing record 3 of set 4 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mys shmidta
# City not found!
# Processing record 4 of set 4 | ruhengeri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ruhengeri
# Processing record 5 of set 4 | dawlatabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=dawlatabad
# Processing record 6 of set 4 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=esperance
# Processing record 7 of set 4 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=port shepstone
# Processing record 8 of set 4 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ballina
# Processing record 9 of set 4 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=georgetown
# Processing record 10 of set 4 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=meyungs
# City not found!
# Processing record 11 of set 4 | bae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bae
# Processing record 12 of set 4 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ilulissat
# Processing record 13 of set 4 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=yulara
# Processing record 14 of set 4 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=vaitupu
# City not found!
# Processing record 15 of set 4 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=broome
# Processing record 16 of set 4 | dubbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=dubbo
# Processing record 17 of set 4 | jamame
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=jamame
# Processing record 18 of set 4 | kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kenora
# Processing record 19 of set 4 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=constitucion
# Processing record 20 of set 4 | tabory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tabory
# Processing record 21 of set 4 | larap
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=larap
# Processing record 22 of set 4 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=half moon bay
# Processing record 23 of set 4 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cayenne
# Processing record 24 of set 4 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=halalo
# City not found!
# Processing record 25 of set 4 | elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=elko
# Processing record 26 of set 4 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=leningradskiy
# Processing record 27 of set 4 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=dikson
# Processing record 28 of set 4 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=geraldton
# Processing record 29 of set 4 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lavrentiya
# Processing record 30 of set 4 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=amapa
# Processing record 31 of set 4 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hualmay
# Processing record 32 of set 4 | umtata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=umtata
# Processing record 33 of set 4 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=arraial do cabo
# Processing record 34 of set 4 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lakes entrance
# Processing record 35 of set 4 | waycross
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=waycross
# Processing record 36 of set 4 | sainte-marie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sainte-marie
# Processing record 37 of set 4 | sherbakul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sherbakul
# Processing record 38 of set 4 | bronzani majdan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bronzani majdan
# Processing record 39 of set 4 | alangudi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=alangudi
# Processing record 40 of set 4 | reykjavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=reykjavik
# Processing record 41 of set 4 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=torbay
# Processing record 42 of set 4 | irtyshskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=irtyshskiy
# Processing record 43 of set 4 | boa vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=boa vista
# Processing record 44 of set 4 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sentyabrskiy
# City not found!
# Processing record 45 of set 4 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=touros
# Processing record 46 of set 4 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=huarmey
# Processing record 47 of set 4 | ylivieska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ylivieska
# Processing record 48 of set 4 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=port elizabeth
# Processing record 49 of set 4 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=grindavik
# Processing record 50 of set 4 | lapua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lapua
# Processing record 0 of set 5 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=jumla
# Processing record 1 of set 5 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ornskoldsvik
# Processing record 2 of set 5 | port-de-paix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=port-de-paix
# City not found!
# Processing record 3 of set 5 | tshikapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tshikapa
# Processing record 4 of set 5 | cam pha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cam pha
# City not found!
# Processing record 5 of set 5 | marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=marystown
# Processing record 6 of set 5 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=dwarka
# Processing record 7 of set 5 | nizhniy tsasuchey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nizhniy tsasuchey
# Processing record 8 of set 5 | nkhotakota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nkhotakota
# Processing record 9 of set 5 | menongue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=menongue
# Processing record 10 of set 5 | lewiston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lewiston
# Processing record 11 of set 5 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sao filipe
# Processing record 12 of set 5 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=pacific grove
# Processing record 13 of set 5 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sept-iles
# Processing record 14 of set 5 | mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mana
# Processing record 15 of set 5 | tartus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tartus
# Processing record 16 of set 5 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=maniitsoq
# Processing record 17 of set 5 | phalombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=phalombe
# Processing record 18 of set 5 | mega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mega
# Processing record 19 of set 5 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kalmunai
# Processing record 20 of set 5 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=khatanga
# Processing record 21 of set 5 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=champerico
# Processing record 22 of set 5 | searcy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=searcy
# Processing record 23 of set 5 | houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=houma
# Processing record 24 of set 5 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=acapulco
# Processing record 25 of set 5 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=takoradi
# Processing record 26 of set 5 | alotau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=alotau
# City not found!
# Processing record 27 of set 5 | mae hong son
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mae hong son
# Processing record 28 of set 5 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=haines junction
# Processing record 29 of set 5 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tautira
# Processing record 30 of set 5 | manzhouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=manzhouli
# Processing record 31 of set 5 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lolua
# City not found!
# Processing record 32 of set 5 | kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kiunga
# Processing record 33 of set 5 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=port hardy
# Processing record 34 of set 5 | portage
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=portage
# Processing record 35 of set 5 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=stornoway
# Processing record 36 of set 5 | hecun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hecun
# Processing record 37 of set 5 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kazalinsk
# City not found!
# Processing record 38 of set 5 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=makakilo city
# Processing record 39 of set 5 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=portland
# Processing record 40 of set 5 | wasilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=wasilla
# Processing record 41 of set 5 | dehloran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=dehloran
# Processing record 42 of set 5 | myitkyina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=myitkyina
# Processing record 43 of set 5 | caratinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=caratinga
# Processing record 44 of set 5 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hami
# Processing record 45 of set 5 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=naze
# Processing record 46 of set 5 | podgorica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=podgorica
# Processing record 47 of set 5 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=alice springs
# Processing record 48 of set 5 | ous
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ous
# Processing record 49 of set 5 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=saskylakh
# Processing record 50 of set 5 | cotonou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cotonou
# Processing record 0 of set 6 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sola
# Processing record 1 of set 6 | ryotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ryotsu
# Processing record 2 of set 6 | ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ternate
# Processing record 3 of set 6 | mango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mango
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lovozero
# Processing record 46 of set 9 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=belaya gora
# Processing record 47 of set 9 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sabang
# Processing record 48 of set 9 | palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=palu
# Processing record 49 of set 9 | cascais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cascais
# Processing record 50 of set 9 | iroquois falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=iroquois falls
# Processing record 0 of set 10 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=harper
# Processing record 1 of set 10 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kangaatsiaq
# Processing record 2 of set 10 | azare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=azare
# Processing record 3 of set 10 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=thunder bay
# Processing record 4 of set 10 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=katsuura
# Processing record 5 of set 10 | bombay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bombay
# Processing record 6 of set 10 | sawai madhopur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sawai madhopur
# Processing record 7 of set 10 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ketchikan
# Processing record 8 of set 10 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=pangnirtung
# Processing record 9 of set 10 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tabou
# Processing record 10 of set 10 | ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ust-kamchatsk
# City not found!
# Processing record 11 of set 10 | west bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=west bay
# Processing record 12 of set 10 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=udachnyy
# Processing record 13 of set 10 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=buraydah
# Processing record 14 of set 10 | mariental
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mariental
# Processing record 15 of set 10 | pafos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=pafos
# Processing record 16 of set 10 | yermakovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=yermakovskoye
# Processing record 17 of set 10 | lermontovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lermontovka
# Processing record 18 of set 10 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lompoc
# Processing record 19 of set 10 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=alofi
# Processing record 20 of set 10 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sao gabriel da cachoeira
# Processing record 21 of set 10 | de-kastri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=de-kastri
# Processing record 22 of set 10 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lata
# Processing record 23 of set 10 | inongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=inongo
# Processing record 24 of set 10 | swabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=swabi
# Processing record 25 of set 10 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kununurra
# Processing record 26 of set 10 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=khani
# Processing record 27 of set 10 | khor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=khor
# Processing record 28 of set 10 | zabaykalsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=zabaykalsk
# Processing record 29 of set 10 | cartagena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=cartagena
# Processing record 30 of set 10 | surovatikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=surovatikha
# Processing record 31 of set 10 | minsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=minsk
# Processing record 32 of set 10 | concepcion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=concepcion
# Processing record 33 of set 10 | sharanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=sharanga
# Processing record 34 of set 10 | paralimni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=paralimni
# Processing record 35 of set 10 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=karratha
# Processing record 36 of set 10 | abay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=abay
# Processing record 37 of set 10 | labutta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=labutta
# City not found!
# Processing record 38 of set 10 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=pangody
# Processing record 39 of set 10 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=port hedland
# Processing record 40 of set 10 | talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=talara
# Processing record 41 of set 10 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=antalaha
# Processing record 42 of set 10 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=margate
# Processing record 43 of set 10 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=severo-kurilsk
# Processing record 44 of set 10 | askino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=askino
# Processing record 45 of set 10 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=maldonado
# Processing record 46 of set 10 | ouadda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ouadda
# Processing record 47 of set 10 | karagaylinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=karagaylinskiy
# Processing record 48 of set 10 | tashara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tashara
# Processing record 49 of set 10 | varhaug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=varhaug
# Processing record 50 of set 10 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=hay river
# Processing record 0 of set 11 | dimbokro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=dimbokro
# Processing record 1 of set 11 | kalaiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kalaiya
# Processing record 2 of set 11 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tezu
# Processing record 3 of set 11 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tilichiki
# Processing record 4 of set 11 | dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=dalvik
# Processing record 5 of set 11 | nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nago
# Processing record 6 of set 11 | kamyshlov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kamyshlov
# Processing record 7 of set 11 | conchal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=conchal
# Processing record 8 of set 11 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=talcahuano
# Processing record 9 of set 11 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=marsh harbour
# Processing record 10 of set 11 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=fukue
# Processing record 11 of set 11 | satipo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=satipo
# Processing record 12 of set 11 | presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=presidencia roque saenz pena
# Processing record 13 of set 11 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=nome
# Processing record 14 of set 11 | iwanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=iwanai
# Processing record 15 of set 11 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mehamn
# Processing record 16 of set 11 | mount pleasant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=mount pleasant
# Processing record 17 of set 11 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=broken hill
# Processing record 18 of set 11 | gayny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=gayny
# Processing record 19 of set 11 | suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=suntar
# Processing record 20 of set 11 | saleilua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=saleilua
# City not found!
# Processing record 21 of set 11 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=saint-pierre
# Processing record 22 of set 11 | ban nahin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=ban nahin
# Processing record 23 of set 11 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=fairbanks
# Processing record 24 of set 11 | kirksville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kirksville
# Processing record 25 of set 11 | artesia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=artesia
# Processing record 26 of set 11 | zhaotong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=zhaotong
# Processing record 27 of set 11 | williston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=williston
# Processing record 28 of set 11 | dongsheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=dongsheng
# Processing record 29 of set 11 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=lac du bonnet
# Processing record 30 of set 11 | bayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=bayan
# Processing record 31 of set 11 | albion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=albion
# Processing record 32 of set 11 | magaria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=magaria
# Processing record 33 of set 11 | calafell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=calafell
# Processing record 34 of set 11 | arvika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=arvika
# Processing record 35 of set 11 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=kahului
# Processing record 36 of set 11 | boa viagem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=boa viagem
# Processing record 37 of set 11 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=aksarka
# Processing record 38 of set 11 | malindi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=malindi
# Processing record 39 of set 11 | columbus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=columbus
# Processing record 40 of set 11 | glendive
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=glendive
# Processing record 41 of set 11 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=anadyr
# Processing record 42 of set 11 | suez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=suez
# Processing record 43 of set 11 | syamzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=syamzha
# Processing record 44 of set 11 | acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=acajutla
# Processing record 45 of set 11 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ae1fca35e0586e04572f2c0ff31f738&q=tual
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          556
# Cloudiness    556
# Country       556
# Date          556
# Humidity      556
# Temp          556
# Lat           556
# Lng           556
# Wind Speed    556
# dtype: int64

# %%
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0      rikitea           8      PF  1580101465        83  79.12 -23.12
# 1    hithadhoo          79      MV  1580101278        80  82.22  -0.60
# 2       hobart          48      AU  1580101465        30  72.00 -42.88
# 3       albany          90      US  1580101465       100  37.99  42.60
# 4  mujiayingzi         100      CN  1580101466        27  33.42  42.12
#
#       Lng  Wind Speed
# 0 -134.97        7.40
# 1   73.08       11.61
# 2  147.33       17.22
# 3  -73.97        4.70
# 4  118.78        3.33

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Output to a csv 
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)

# Set variable for output file
output_file = os.path.join('..','output_data', 'cities.csv')

#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %%
# use datetime 
date =datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')

# %%
weather_data.plot(kind='scatter', x='Lat', y='Temp', c='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("Fig1.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("Fig2.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='DarkBlue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("Fig3.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='DarkBlue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("Fig3.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def linear_reg_plot(df, title_name, y_column_name, y_label, file_name, xy):
    x_values = df['Lat']
    y_values = df[y_column_name]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.annotate(line_eq,xy,fontsize=15,color="red")
    plt.title(title_name)
    
    print(f"The r-squared is: {rvalue}")
    
    plt.savefig(file_name)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = weather_data.loc[weather_data['Lat'] > 0, :]
southern_hemisphere_df = weather_data.loc[weather_data['Lat'] < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Max Temp Vs Latitude Regression', 'Temp', 'Temp', '../output_data/NorthernMaxTempVsLatitudeReg.png', (10,0))
# Out:
# The r-squared is: -0.8924563048884262

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Max Temp Vs Latitude Regression', 'Temp', 'Temp', '../output_data/SouthernMaxTempVsLatitudeReg.png', (-40,50))
# Out:
# The r-squared is: 0.43714542640412146

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Humidity Vs. Latitude Regression', 'Humidity', 'Humidity', '../output_data/NorthernHumidityVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: 0.3454955107722853

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Humidity Vs. Latitude Regression', 'Humidity', 'Humidity', '../output_data/SouthernHumidityVsLatitudeReg.png', (-50,20))
# Out:
# The r-squared is: 0.24687259214394075

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Cloudiness Vs. Latitude Regression', 'Cloudiness', 'Cloudiness', '../output_data/NorthernCloudinessVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: 0.31497756482516004

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Cloudiness Vs. Latitude Regression', 'Cloudiness', 'Cloudiness', '../output_data/SouthernCloudinessVsLatitudeReg.png', (-50,20))
# Out:
# The r-squared is: 0.29461559053945563

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Wind Speed Vs. Latitude Regression', 'Wind Speed', 'Wind Speed', '../output_data/NorthernWindSpeedVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: 0.021595960038188117

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Wind Speed Vs. Southern Hemisphere', 'Wind Speed', 'Wind Speed', '../output_data/SouthernWindSpeedVsLatitudeReg.png', (-30,20))
# Out:
# The r-squared is: -0.2550635511455826
